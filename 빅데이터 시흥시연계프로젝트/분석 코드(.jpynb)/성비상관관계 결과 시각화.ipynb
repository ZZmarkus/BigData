# %%
import pandas as pd
from scipy import stats
from statsmodels.formula.api import ols, glm
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corr = pd.read_excel("C:\\Users\\masterT\\Desktop\\시흥시프로젝트\\정제 후 데이터\\연령-성비(남,여) 사고분석.xlsx")
corr
# Out:
#    ~20  21~30  31~40  41~50  51~60  61~64  65~  Male  Female
# 0   68    418    532    716    346     61   48  1861     328
# 1   73    324    484    670    377     61   62  1744     304
# 2   70    325    507    649    443     71   68  1810     325
# 3   52    288    410    555    427     68   77  1605     269
# 4   58    268    382    539    452     84   97  1581     299
# 5   70    320    439    574    588     95  145  1871     359
# 6   69    310    386    569    520    115  131  1740     359
# 7   80    320    416    488    549    135  147  1753     382
# 8   62    347    455    512    664    149  195  1932     452
# 9   69    358    389    451    578    190  226  1853     409

# %%
sex_corr = corr.corr(method = 'pearson')

# %%
sex_corr
# Out:
#              ~20     21~30     31~40     41~50     51~60     61~64       65~  \
# ~20     1.000000  0.343094  0.245340  0.080749  0.103223  0.214981  0.132350
# 21~30   0.343094  1.000000  0.639200  0.355479 -0.091167  0.131119  0.045530
# 31~40   0.245340  0.639200  1.000000  0.813830 -0.458060 -0.520995 -0.546153
# 41~50   0.080749  0.355479  0.813830  1.000000 -0.772043 -0.837192 -0.850255
# 51~60   0.103223 -0.091167 -0.458060 -0.772043  1.000000  0.812639  0.912177
# 61~64   0.214981  0.131119 -0.520995 -0.837192  0.812639  1.000000  0.965101
# 65~     0.132350  0.045530 -0.546153 -0.850255  0.912177  0.965101  1.000000
# Male    0.442630  0.749928  0.473671  0.053653  0.466419  0.408808  0.440409
# Female  0.348955  0.383710 -0.116390 -0.541184  0.844060  0.847970  0.854106
#
#             Male    Female
# ~20     0.442630  0.348955
# 21~30   0.749928  0.383710
# 31~40   0.473671 -0.116390
# 41~50   0.053653 -0.541184
# 51~60   0.466419  0.844060
# 61~64   0.408808  0.847970
# ...

# %%
f,ax = plt.subplots(1, 2, figsize = (10, 5))

# %%
sns.pairplot(sex_corr)

# %%
heatmap_data = sex_corr[['~20', '21~30', '31~40', '41~50', '51~60', '61~64', '65~', 'Male', 'Female']]

# %%
colormap = plt.cm.RdBu

# %%
sns.heatmap(heatmap_data.astype(float).corr(), linewidths = 0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={'size':7})
# Out:
# <AxesSubplot:>
